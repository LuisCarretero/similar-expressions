# %% [markdown]
# ## Analyzing generated dataset

# %% [markdown]
# ### Import data

# %%
# Add path
import os
import sys
project_root = os.path.dirname(os.path.dirname(os.path.abspath('')))  # similar-expressions/
sys.path.insert(0, project_root)

# Reload modules
from importlib import reload
from src.model import encoder, decoder
from src.utils import dataset, config, dev, dataset_dev, parsing, grammar
reload(decoder); reload(encoder); reload(dataset); reload(config); reload(dev); reload(dataset_dev); reload(parsing); reload(grammar); reload(grammar)

from src.utils.dataset_analysis import plot_value_distributions, analyze_outliers, analyze_sequences, analyze_syntax_tokens, plot_values
from src.utils.dataset import load_dataset, create_dataloader, create_value_transform

import numpy as np
import torch
from matplotlib import pyplot as plt
# Out:
# /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/onnxscript/converter.py:823: FutureWarning: 'onnxscript.values.Op.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/onnxscript/converter.py:823: FutureWarning: 'onnxscript.values.OnnxFunction.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()

# %%
datapath = '/cephfs/store/gr-mc2473/lc865/workspace/data/'
syntax, consts, values, val_x, syntax_cats = load_dataset(datapath, 'dataset_250302_1', max_length=int(1e6))
print(syntax_cats)

# %%
val_transformed = np.arcsinh(values)

i = 40
plot_values(val_x, values, val_transformed, idx=np.arange(i, i+20))

# %% [markdown]
# ### Analyze dataset

# %%
plot_value_distributions(values, val_transformed)
analyze_outliers(val_transformed)
# Out:
# Number of outliers detected using z-score method: 2083840
# Number of outliers detected using IQR method: 5994659

# %%
i = 30
plot_values(val_x, values, val_transformed, idx=np.arange(i, i+20))

# %%
mask = (syntax[:, :, syntax_cats.index('CON')] == 1)
active_consts = consts[mask]

plot_value_distributions(active_consts, active_consts)
analyze_outliers(active_consts)
# Out:
# Number of outliers detected using z-score method: 5143
# Number of outliers detected using IQR method: 13094

# %%
analyze_syntax_tokens(syntax, syntax_cats)
analyze_sequences(syntax, syntax_cats)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 analyze_syntax_tokens(syntax, syntax_cats)
# ----> 2 analyze_sequences(syntax, syntax_cats)
#
# File /mhome/damtp/q/lc865/workspace/similar-expressions/src/utils/dataset_analysis.py:166, in analyze_sequences(syntax, categories)
#     163 axs[2, 1].set_xlabel('Similarity (0-1)')
#     164 axs[2, 1].set_ylabel('Count')
# --> 166 plt.tight_layout()
#     167 plt.show()
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/pyplot.py:2801, in tight_layout(pad, h_pad, w_pad, rect)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/figure.py:3545, in tight_layout(self, pad, h_pad, w_pad, rect)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/layout_engine.py:183, in execute(self, fig)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/_tight_layout.py:109, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:959, in get_window_extent(self, renderer, dpi)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:373, in _get_layout(self, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:219, in get_text_width_height_descent(self, s, prop, ismath)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:253, in _prepare_font(self, font_prop)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1386, in _find_fonts_by_props(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1297, in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1448, in _findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1301, in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# ValueError: Failed to find font DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=20.0, and fallback to the default font was disabled
# findfont: Generic family 'sans-serif' not found because none of the following families were found: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# Error in callback <function _draw_all_if_interactive at 0x7f3e386c2520> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/pyplot.py:268, in _draw_all_if_interactive()
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/_pylab_helpers.py:131, in draw_all(cls, force)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backend_bases.py:1905, in draw_idle(self, *args, **kwargs)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:387, in draw(self)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/artist.py:95, in draw_wrapper(artist, renderer, *args, **kwargs)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/artist.py:72, in draw_wrapper(artist, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/figure.py:3162, in draw(self, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/artist.py:72, in draw_wrapper(artist, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:751, in draw(self, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:373, in _get_layout(self, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:219, in get_text_width_height_descent(self, s, prop, ismath)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:253, in _prepare_font(self, font_prop)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1386, in _find_fonts_by_props(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1297, in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1448, in _findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1301, in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# ValueError: Failed to find font DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=20.0, and fallback to the default font was disabled
# findfont: Generic family 'sans-serif' not found because none of the following families were found: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/IPython/core/formatters.py:343, in __call__(self, obj)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backend_bases.py:2175, in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/artist.py:95, in draw_wrapper(artist, renderer, *args, **kwargs)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/artist.py:72, in draw_wrapper(artist, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/figure.py:3162, in draw(self, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/artist.py:72, in draw_wrapper(artist, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:751, in draw(self, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:373, in _get_layout(self, renderer)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:219, in get_text_width_height_descent(self, s, prop, ismath)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:253, in _prepare_font(self, font_prop)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1386, in _find_fonts_by_props(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1297, in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1448, in _findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#
# File /cephfs/store/gr-mc2473/lc865/misc/condaforge/envs/ml/lib/python3.12/site-packages/matplotlib/font_manager.py:1301, in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#
# ValueError: Failed to find font DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=20.0, and fallback to the default font was disabled

# %% [markdown]
# ## Check if normalisation sent any functions to oblivion

# %%
values.min(), values.max()
# Out:
# (np.float32(-0.97374535), np.float32(2.25))

# %% [markdown]
# ## Dev for new filter functions
#
# Filters:
# - Absolute value
# - 1st derivative

# %%
from matplotlib import pyplot as plt

# %%
print(f"Values min: {values.min()}, max: {values.max()}")

# Calculate first derivative over each row
first_derivative = np.diff(values, axis=1)/np.diff(val_x, axis=0).T
print(f"First derivative min: {first_derivative.min()}, max: {first_derivative.max()}")
# Out:
# Values min: -99999.5, max: 99999.5
# First derivative min: -369679.6875, max: 332179.34375

# %% [markdown]
# ### Idea: Work with fourier components
# - large freq amplitudes -> 0
# - Inspired by DL lectures

# %%
C_f
# Out:
# array([2.58551955e+04, 2.09603823e+02, 1.74372740e+04, 1.84029818e+03,
#        1.31715839e+02, 2.02719247e+06, 0.00000000e+00, 3.09525017e+03,
#        2.11226995e+06, 2.11226996e+06])

# %%
C_f = np.sum(np.abs(freqs * ft), axis=1)

# %%
# FFT test
from matplotlib import pyplot as plt

a = values[:10, :]
ft = np.fft.fft(a, axis=1)
freqs = np.fft.fftfreq(a.shape[1], d=val_x[1]-val_x[0])

plt.plot(freqs[freqs>=0], np.abs(ft[0, freqs>=0])**2)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Derivative filters

# %%
deriv_thresholds = np.array([100, 100, 100, 100]) * 3

first_derivative = np.diff(val_transformed, axis=1) / np.diff(val_x, axis=0).T
second_derivative = np.diff(first_derivative, axis=1) / np.diff(val_x[:-1], axis=0).T
third_derivative = np.diff(second_derivative, axis=1) / np.diff(val_x[:-2], axis=0).T
fourth_derivative = np.diff(third_derivative, axis=1) / np.diff(val_x[:-3], axis=0).T
is_valid = (np.all(np.abs(first_derivative) < deriv_thresholds[0], axis=1) & \
            np.all(np.abs(second_derivative) < deriv_thresholds[1], axis=1) & \
            np.all(np.abs(third_derivative) < deriv_thresholds[2], axis=1) & \
            np.all(np.abs(fourth_derivative) < deriv_thresholds[3], axis=1))

# %%
is_valid.sum() / len(is_valid)
# Out:
# np.float64(1.0)

# %%
# Plot the ith function (raw values, transformed values, and derivatives)
i, n = 20, 10  # Using the same index as in the previous example

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(8, 12))

# Plot raw values
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax1.plot(val_x, values[i+j, :], linestyle=linestyle)
ax1.set_title('Raw Values')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

# Plot transformed values
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax2.plot(val_x, val_transformed[i+j, :], linestyle=linestyle)
ax2.set_title('Transformed Values')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

# Plot first derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax3.plot(val_x[1:], first_derivative[i+j, :], linestyle=linestyle)
ax3.set_title('First Derivative')
ax3.set_xlabel('x')
ax3.set_ylabel('dy/dx')

# Plot second derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax4.plot(val_x[2:], second_derivative[i+j, :], linestyle=linestyle)
ax4.set_title('Second Derivative')
ax4.set_xlabel('x')
ax4.set_ylabel('d²y/dx²')

# Plot third derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax5.plot(val_x[3:], third_derivative[i+j, :], linestyle=linestyle)
ax5.set_title('Third Derivative')
ax5.set_xlabel('x')
ax5.set_ylabel('d³y/dx³')

# Plot fourth derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax6.plot(val_x[4:], fourth_derivative[i+j, :], linestyle=linestyle)
ax6.set_title('Fourth Derivative')
ax6.set_xlabel('x')
ax6.set_ylabel('d⁴y/dx⁴')

plt.tight_layout()
plt.show()

# %%
i = 120
plot_values(val_x, values, val_transformed, idx=np.arange(i, i+10))
