# %% [markdown]
# ## Analyzing generated dataset

# %% [markdown]
# ### Import data

# %%
import os
import sys
project_root = os.path.dirname(os.path.abspath(''))
sys.path.insert(0, project_root)
sys.path.insert(0, os.path.join(project_root, 'model'))
sys.path.insert(0, os.path.join(project_root, 'dataset_generation'))

from importlib import reload
import analysis_util
import util
reload(analysis_util)
reload(util)

from analysis_util import analyze_outliers, plot_value_distributions, analyze_sequences, analyze_syntax_tokens, plot_values
from data_util import load_dataset, create_dataloader, create_value_transform
from util import load_config
import pandas as pd
import numpy as np
import torch
from matplotlib import pyplot as plt

# %%
from data_util import calc_priors_and_means, load_wandb_model, create_dataloader_from_wandb

model, cfg = load_wandb_model(run='om4vbk2m', name='last.ckpt', project='simexp-03', replace=True, fallback_cfg_path='../model/config.yaml')
train_loader, test_loader, info = create_dataloader_from_wandb(cfg)
priors, means = calc_priors_and_means(train_loader)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from data_util import calc_priors_and_means, load_wandb_model, create_dataloader_from_wandb
# ----> 3 model, cfg = load_wandb_model(run='om4vbk2m', name='last.ckpt', project='simexp-03', replace=True, fallback_cfg_path='../model/config.yaml')
#       4 train_loader, test_loader, info = create_dataloader_from_wandb(cfg)
#       5 priors, means = calc_priors_and_means(train_loader)
#
# File ~/Desktop/Cranmer2024/Workplace/smallMutations/similar-expressions/src/model/data_util.py:204, in load_wandb_model(run, name, device, wandb_cache_path, project, replace, fallback_cfg_path)
#     202 def load_wandb_model(run: str, name:str = 'model.pth', device='cpu', wandb_cache_path='/Users/luis/Desktop/Cranmer2024/Workplace/smallMutations/similar-expressions/wandb_cache', project='similar-expressions-01', replace=True, fallback_cfg_path='config.yaml'):
#     203     # Load model
# --> 204     with wandb.restore(name, run_path=f"luis-carretero-eth-zurich/{project}/runs/{run}", root=wandb_cache_path, replace=replace) as io:
#     205         name = io.name
#     207     # Read the model parameters from the WandB config.yaml file
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/wandb/sdk/wandb_run.py:4222, in restore(name, run_path, replace, root)
#    4220 if files[0].md5 == "0":
#    4221     raise ValueError(f"File {name} not found in {run_path or root}.")
# -> 4222 return files[0].download(root=root, replace=True)
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/wandb/apis/public/files.py:172, in File.download(self, root, replace, exist_ok, api)
#     167     else:
#     168         raise ValueError(
#     169             "File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error."
#     170         )
# --> 172 util.download_file_from_url(path, self.url, api.api_key)
#     173 return open(path)
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/wandb/util.py:1326, in download_file_from_url(dest_path, source_url, api_key)
#    1324     filesystem.mkdir_exists_ok(os.path.dirname(dest_path))
#    1325 with fsync_open(dest_path, "wb") as file:
# -> 1326     for data in response.iter_content(chunk_size=1024):
#    1327         file.write(data)
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/urllib3/response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/urllib3/response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/urllib3/response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/site-packages/urllib3/response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/simexpr-arm64/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
priors
# Out:
# {'syntax_prior': np.float32(1.6957272),
#  'consts_prior': np.float32(0.06632848),
#  'values_prior': tensor(1.9573e-06)}

# %%
datapath = '/Users/luis/Desktop/Cranmer2024/Workplace/smallMutations/similar-expressions/data'
syntax, consts, values, val_x, syntax_cats = load_dataset(datapath, 'dataset_241207_3')

# %%
import data_util
reload(data_util)
from data_util import create_value_transform

# cfg = load_config('../model/config.yaml', fallback_cfg_path='../model/config.yaml')
# value_transform = create_value_transform(cfg.training.value_transform, torch.tensor(values))
# val_transformed = value_transform(torch.tensor(values)).detach().numpy()
val_transformed = values

i = 120
plot_values(val_x, values, val_transformed, idx=np.arange(i, i+20))

# %% [markdown]
# ### Analyze dataset

# %%
plot_value_distributions(values, val_transformed)
analyze_outliers(val_transformed)
# Out:
# Number of outliers detected using z-score method: 6
# Number of outliers detected using IQR method: 0

# %%
i = 40
plot_values(val_x, values, val_transformed, idx=np.arange(i, i+20))

# %%
mask = (syntax[:, :, syntax_cats.index('CON')] == 1)
active_consts = consts[mask]

plot_value_distributions(active_consts, active_consts)
analyze_outliers(active_consts)
# Out:
# Number of outliers detected using z-score method: 1975
# Number of outliers detected using IQR method: 4632

# %%
analyze_syntax_tokens(syntax, syntax_cats)
analyze_sequences(syntax, syntax_cats)

# %% [markdown]
# ## Check if normalisation sent any functions to oblivion

# %%
values.min(), values.max()
# Out:
# (np.float32(-0.97374535), np.float32(2.25))

# %% [markdown]
# ## Dev for new filter functions
#
# Filters:
# - Absolute value
# - 1st derivative

# %%
from matplotlib import pyplot as plt

# %%
print(f"Values min: {values.min()}, max: {values.max()}")

# Calculate first derivative over each row
first_derivative = np.diff(values, axis=1)/np.diff(val_x, axis=0).T
print(f"First derivative min: {first_derivative.min()}, max: {first_derivative.max()}")
# Out:
# Values min: -99999.5, max: 99999.5
# First derivative min: -369679.6875, max: 332179.34375

# %% [markdown]
# ### Idea: Work with fourier components
# - large freq amplitudes -> 0
# - Inspired by DL lectures

# %%
C_f
# Out:
# array([2.58551955e+04, 2.09603823e+02, 1.74372740e+04, 1.84029818e+03,
#        1.31715839e+02, 2.02719247e+06, 0.00000000e+00, 3.09525017e+03,
#        2.11226995e+06, 2.11226996e+06])

# %%
C_f = np.sum(np.abs(freqs * ft), axis=1)

# %%
# FFT test
from matplotlib import pyplot as plt

a = values[:10, :]
ft = np.fft.fft(a, axis=1)
freqs = np.fft.fftfreq(a.shape[1], d=val_x[1]-val_x[0])

plt.plot(freqs[freqs>=0], np.abs(ft[0, freqs>=0])**2)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Derivative filters

# %%
deriv_thresholds = np.array([100, 100, 100, 100]) * 3

first_derivative = np.diff(val_transformed, axis=1) / np.diff(val_x, axis=0).T
second_derivative = np.diff(first_derivative, axis=1) / np.diff(val_x[:-1], axis=0).T
third_derivative = np.diff(second_derivative, axis=1) / np.diff(val_x[:-2], axis=0).T
fourth_derivative = np.diff(third_derivative, axis=1) / np.diff(val_x[:-3], axis=0).T
is_valid = (np.all(np.abs(first_derivative) < deriv_thresholds[0], axis=1) & \
            np.all(np.abs(second_derivative) < deriv_thresholds[1], axis=1) & \
            np.all(np.abs(third_derivative) < deriv_thresholds[2], axis=1) & \
            np.all(np.abs(fourth_derivative) < deriv_thresholds[3], axis=1))

# %%
is_valid.sum() / len(is_valid)
# Out:
# np.float64(0.9406228899392303)

# %%
# Plot the ith function (raw values, transformed values, and derivatives)
i, n = 80, 10  # Using the same index as in the previous example

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(8, 12))

# Plot raw values
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax1.plot(val_x, values[i+j, :], linestyle=linestyle)
ax1.set_title('Raw Values')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

# Plot transformed values
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax2.plot(val_x, val_transformed[i+j, :], linestyle=linestyle)
ax2.set_title('Transformed Values')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

# Plot first derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax3.plot(val_x[1:], first_derivative[i+j, :], linestyle=linestyle)
ax3.set_title('First Derivative')
ax3.set_xlabel('x')
ax3.set_ylabel('dy/dx')

# Plot second derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax4.plot(val_x[2:], second_derivative[i+j, :], linestyle=linestyle)
ax4.set_title('Second Derivative')
ax4.set_xlabel('x')
ax4.set_ylabel('d²y/dx²')

# Plot third derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax5.plot(val_x[3:], third_derivative[i+j, :], linestyle=linestyle)
ax5.set_title('Third Derivative')
ax5.set_xlabel('x')
ax5.set_ylabel('d³y/dx³')

# Plot fourth derivative
for j in range(n):
    linestyle = '-' if is_valid[i+j] else ':'
    ax6.plot(val_x[4:], fourth_derivative[i+j, :], linestyle=linestyle)
ax6.set_title('Fourth Derivative')
ax6.set_xlabel('x')
ax6.set_ylabel('d⁴y/dx⁴')

plt.tight_layout()
plt.show()

# %%
i = 120
plot_values(val_x, values, val_transformed, idx=np.arange(i, i+10))
